# %% [markdown]
# <a href="https://colab.research.google.com/github/sanikachiddarwar/python-pep/blob/main/collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
fruit=["apple","apple","apple","banana","kiwi","mango","mango","kiwi"]
count=Counter(fruit)
print(count)
# Out:
# Counter({'apple': 3, 'kiwi': 2, 'mango': 2, 'banana': 1})

# %%
list="hello"
count=Counter(list)
print(count)
# Out:
# Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})

# %%
sentence="python is easy and python is powerful"
count=Counter(sentence.split())
print(count)
# Out:
# Counter({'python': 2, 'is': 2, 'easy': 1, 'and': 1, 'powerful': 1})

# %%
list1=[1,2,2,2,4,4,3,2,2,1,2,3,3,4,4,2,1,1,1,1,]
count=Counter(list1)
print(count)
# Out:
# Counter({2: 7, 1: 6, 4: 4, 3: 3})

# %%
import os
current_path=os.getcwd()
print(current_path)
# Out:
# /content

# %%
item=os.listdir()
print(item)
# Out:
# ['.config', 'sample_data']

# %%
import os
folder_name="myfolder"
if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print("folder created")
else:
    print("folder already exists")
# Out:
# folder created
