# %%
marks=[10,20,30,40]
print(marks[3])
marks.append(100)
print(marks)
marks.insert(1,75)
print(marks)
marks.remove(75)
marks.pop()
print(marks)
# Out:
# 40
# [10, 20, 30, 40, 100]
# [10, 75, 20, 30, 40, 100]
# [10, 20, 30, 40]

# %%
age=[23,45,64,12,10,4]
age.sort()
age.reverse()
print(age)
print(max(age))
print(sum(age))
print(sum(age)/len(age))
# Out:
# [64, 45, 23, 12, 10, 4]
# 64
# 158
# 26.333333333333332

# %%
city=["nanded","pune","hyd","mumbai","delhi"]
city[3]
city.append("kinwat")
city.insert(1,"raipur")
city.remove("delhi")
city.pop()
print(city.reverse())
city.sort()
print(len(city))
print(city)
# Out:
# None
# 5
# ['hyd', 'mumbai', 'nanded', 'pune', 'raipur']

# %%
days=('mon','tus','wed','thur','fri','sat','sun')
print(days[0])
print(days[-1])
print(days.count('mon'))
print(days.index('tus'))
print(days[1:3])
# Out:
# mon
# sun
# 1
# 1
# ('tus', 'wed')

# %%
friends=('sanika','harsh','kajal','pranav','ishani')
print(friends[3])
print(friends.count('sanika'))
print(friends.index('kajal'))
print(friends[1:3])
# Out:
# pranav
# 1
# 2
# ('harsh', 'kajal')

# %%
numbers={10,20,30,45,231,456}
print(numbers)

for i in numbers:
  print(i)
numbers.add(100)
numbers.update([120,130])
numbers.remove(100)
numbers.discard(400)
print(numbers)
# Out:
# {20, 231, 456, 10, 45, 30}
# 20
# 231
# 456
# 10
# 45
# 30
# {130, 456, 10, 20, 30, 231, 45, 120}

# %%
a={1,2,3,4}
b={5,3,4,6,}
print(a.intersection(b))
print(a.union(b))
print(a.difference(b))
print(b.difference(a))
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# {5, 6}

# %%
marks1={79,76,60,36,98,80}
marks2={36,67,86,80,78,86}
print(marks1.intersection(marks2))
print(marks1.union(marks2))
print(marks1)
print(marks2)
# Out:
# {80, 36}
# {98, 67, 36, 76, 78, 79, 80, 86, 60}
# {80, 98, 36, 76, 60, 79}
# {80, 67, 36, 86, 78}
