# %%
#append in list
fruit=[]
print(fruit)
fruit.append("apple")
print(fruit)
# Out:
# []
# ['apple']

# %%
#sum of all the elements in list
num=[5,6,10,15]
total=0
for i in numbers:
   total=total+i
   print(total)

# %%
#reversing the string
nums=[1,2,3,40]
reverse=nums[::-1]
print(reverse)
# Out:
# [40, 3, 2, 1]

# %%
#removing duplicate form the list
num1=[1,2,3,4,4,2,1]
uni=[]
for i in  nums:
   if i not in uni:
      uni.append(i)
      print(uni)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]
# [1, 2, 3, 40]

# %%
#accessind 2 and 3 elememts
colors=('red','green','blue')
print(colors[2])
print(colors[1])
# Out:
# blue
# green

# %%
#converting list to tuple
num2=[1,2,3,4]
print(type(num2))
num_tuple=tuple(num2)
print(type(num_tuple))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
#converting tuple to list
colors=("red","green","blue")
print(type(colors))
colors_list=list(colors)
print(type(colors_list))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
# converting list to set
num3=[1,2,3,3,4,4]
print(type(num3))
num_set=set(num3)
print(type(num_set))
num_list=list(num_set)
print(type(num_list))
# Out:
# <class 'list'>
# <class 'set'>
# <class 'list'>

# %%
#comverting dict to sets
num4={"name":"sanika","age":"21"}
print(type(num4))
num_set=set(num4)
print(type(num_set))
print(num_set)
# Out:
# <class 'dict'>
# <class 'set'>
# {'age', 'name'}

# %%
#conversion of set to dict
sub={"maths","hindi","english"}
sub_dict=dict.fromkeys(sub,0)
print(sub_dict)
# Out:
# {'english': 0, 'hindi': 0, 'maths': 0}

# %% [markdown]
# zeroDivisionError-when you divide any number with 0-->print(10/0)
#
# ValurError-when you give wrong dta type to the function-->num=int("abc")
#
# TyprError-when you perform an opreation btw diff data types-->print(5+"abc")
#
# IndexError-when you acess a wrong indexx-->list=[1,2,3]......print(list[5])
#
# keyError-when you try to acsess missing key in a dict-->students={"name":"sanika","age":21}.......but try trying to print marks
#
# FileNotFound-when py not able to find the file in ur pc

# %%
"""try:
  #risky code
except:
  #handling code"""
# Out:
# 'try:\n  #risky code\nexcept:\n  #handling code'

# %%
#catching any specific error
try:
  x=int(input("enter number:"))
  print(10/0)
except ZeroDivisionError:
  print("you cannot divide by zero!")
except ValueError:
  print("enter only numbers")
# Out:
# enter number:67
# you cannpt divide by zero!

# %%
try:
  num=int(input("enter number"))
  print(10/num)
except:
  print("error occured")
else:
  print("no error,program run successfully")
# Out:
# enter number56
# 0.17857142857142858
# no error,program run successfully

# %%
try:
  f=open("movie.txt")
except:
    print("file not found error")
finally:
  print("program finished")
# Out:
# file not found error
# program finished

# %%
age=int(input("enter age:"))
if age<18:               # raise is used to create the own error
  raise ValueError("age must be 18 or above")
print("you can vote")
# Out:
# enter age:34
# you can vote
