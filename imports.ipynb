# %% [markdown]
# <a href="https://colab.research.google.com/github/sanikachiddarwar/python-pep/blob/main/imports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTS**

# %% [markdown]
# *MATHS*

# %%
#Square root
import math
num = 16
print("Square root of the value",num,"is",math.sqrt(num))
# Out:
# Square root of the value 16 is 4.0

# %%
#Power
import math
print(math.pow(2,3))
# Out:
# 8.0

# %%
import math
num = 7.8
print(math.floor(num))     #Floor
print(math.ceil(num))       #cid value
print(math.fabs(8))    #absolute Value
# Out:
# 7
# 8
# 8.0

# %% [markdown]
# *RANDOM*

# %%
import random
dic = random.randint(1,100)      #it will give u a random number btw 1 to 100 in each run
print(dic)
# Out:
# 41

# %%
student = ["Ann","sas","gak","mah","paiu"]
selected = random.choice(student)
print("Congratulations:",selected)
# Out:
# Congratulations: sas

# %%
print(random.randint(1000,9999))
# Out:
# 2470

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-01-30 04:43:12.299394

# %%
date1=datetime.datetime(2026,1,1)
date2=datetime.datetime(2026,1,28)
print(date2-date1)
# Out:
# 27 days, 0:00:00

# %%
today=datetime.date.today()
print(today)
# Out:
# 2026-01-30
